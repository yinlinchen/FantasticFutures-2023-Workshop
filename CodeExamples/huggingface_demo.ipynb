# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/yinlinchen/DCMI-2023-Tutorial/blob/main/CodeExamples/langchain_demo.ipynb)

# %%
# !pip install python-dotenv
# !pip install openai==0.27.2
# !pip install huggingface_hub

# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.llms import HuggingFaceHub
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain


def get_response(llm, template, input_data):
    
    prompt = PromptTemplate(template=template, input_variables=["question"])
    llm_chain = LLMChain(prompt=prompt, llm=llm)
    response = llm_chain.run(input_data)

    return response

# %%
repo_id = "google/flan-t5-xxl"

llm = HuggingFaceHub(
    repo_id=repo_id, model_kwargs={"temperature": 0.1, "max_length": 200}
)

template = """Question: {question}

Answer: Let's think step by step."""

question = "Where is the capital of Canada?"

input_data = {
    "question": question   
}

response = get_response(llm, template, input_data)
print(response)
# Out:
# Ottawa is the capital of Canada. Ottawa is located in Ontario. Ontario is located in Canada. The

# %%
template = "Sentiment analysis for {question}"
question = "I absolutely love the new design. It's innovative, user-friendly, and visually stunning!"

input_data = {
    "question": question   
}

response = get_response(llm, template, input_data)
print(response)
# Out:
# positive

# %%
template = "Sentiment analysis for {question}"
question = "I'm extremely disappointed with the service. It was slow, unresponsive, and completely failed to meet my needs."

input_data = {
    "question": question   
}

response = get_response(llm, template, input_data)
print(response)
# Out:
# negative

# %%
template = "Translate the following English text to French: {question}"
question = "Hello, Fantastic Futures 2023!"

input_data = {
    "question": question   
}

response = get_response(llm, template, input_data)
print(response)
# Out:
# Hello, Fantastic Futures 2023!
